# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f560aea4c884fb8593748eda08bb57f

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "London"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f560aea4c884fb8593748eda08bb57f&q=London

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_decription = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_decription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | cockburn town
# Processing Record 5 of Set 1 | sakaiminato
# Processing Record 6 of Set 1 | eugene
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | dong xoai
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | matara
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | diego de almagro
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | marsabit
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | vardo
# Processing Record 24 of Set 1 | awjilah
# Processing Record 25 of Set 1 | anadyr
# Processing Record 26 of Set 1 | salym
# Processing Record 27 of Set 1 | sangar
# Processing Record 28 of Set 1 | karratha
# Processing Record 29 of Set 1 | ribeira brava
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | ponta delgada
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | tilichiki
# Processing Record 40 of Set 1 | pochutla
# Processing Record 41 of Set 1 | yar-sale
# Processing Record 42 of Set 1 | olafsvik
# Processing Record 43 of Set 1 | les cayes
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | litija
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | marrakesh
# Processing Record 49 of Set 1 | ambovombe
# Processing Record 50 of Set 1 | agua dulce
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | santiago
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | kamenka
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 7 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 2 | nuuk
# Processing Record 9 of Set 2 | barmer
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | qasigiannguit
# Processing Record 16 of Set 2 | korla
# Processing Record 17 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | saint-augustin
# Processing Record 20 of Set 2 | buraydah
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 2 | santa isabel do rio negro
# Processing Record 24 of Set 2 | hami
# Processing Record 25 of Set 2 | itambe
# Processing Record 26 of Set 2 | baker city
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | mocuba
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | barra patuca
# Processing Record 35 of Set 2 | alice springs
# Processing Record 36 of Set 2 | acapulco
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | anito
# Processing Record 39 of Set 2 | aswan
# Processing Record 40 of Set 2 | qui nhon
# Processing Record 41 of Set 2 | saint-louis
# Processing Record 42 of Set 2 | ararangua
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | siay
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | chapleau
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | pattoki
# Processing Record 2 of Set 3 | coahuayana
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | concepcion del uruguay
# Processing Record 5 of Set 3 | constitucion
# Processing Record 6 of Set 3 | guder
# Processing Record 7 of Set 3 | maarianhamina
# Processing Record 8 of Set 3 | westport
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | atuona
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | hualmay
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 16 of Set 3 | amazar
# Processing Record 17 of Set 3 | flin flon
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | borkenes
# Processing Record 21 of Set 3 | vanavara
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | coquimbo
# Processing Record 24 of Set 3 | sohag
# Processing Record 25 of Set 3 | seoul
# Processing Record 26 of Set 3 | griffith
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | saint combs
# City not found. Skipping...
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | nuevo laredo
# Processing Record 31 of Set 3 | necochea
# Processing Record 32 of Set 3 | rawlins
# Processing Record 33 of Set 3 | san quintin
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | walvis bay
# Processing Record 36 of Set 3 | sur
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | paka
# Processing Record 39 of Set 3 | comodoro rivadavia
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | sabang
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | ahipara
# Processing Record 44 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | richards bay
# Processing Record 48 of Set 3 | dakar
# Processing Record 49 of Set 3 | punta arenas
# Processing Record 50 of Set 3 | hyeres
# Processing Record 1 of Set 4 | teya
# Processing Record 2 of Set 4 | bafq
# Processing Record 3 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | muzquiz
# City not found. Skipping...
# Processing Record 6 of Set 4 | lima
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | sandy bay
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | emmett
# Processing Record 13 of Set 4 | lasa
# Processing Record 14 of Set 4 | puerto penasco
# Processing Record 15 of Set 4 | goderich
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | itoman
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | marawi
# Processing Record 21 of Set 4 | santa rosalia
# Processing Record 22 of Set 4 | aasiaat
# Processing Record 23 of Set 4 | dikson
# Processing Record 24 of Set 4 | dunedin
# Processing Record 25 of Set 4 | muisne
# Processing Record 26 of Set 4 | novyy urengoy
# Processing Record 27 of Set 4 | mantua
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | saint anthony
# Processing Record 30 of Set 4 | sao gabriel da cachoeira
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | byron bay
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | bafra
# Processing Record 35 of Set 4 | miyako
# Processing Record 36 of Set 4 | da lat
# Processing Record 37 of Set 4 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 38 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | lakeside
# Processing Record 40 of Set 4 | meulaboh
# Processing Record 41 of Set 4 | vila velha
# Processing Record 42 of Set 4 | beringovskiy
# Processing Record 43 of Set 4 | batemans bay
# Processing Record 44 of Set 4 | riyadh
# Processing Record 45 of Set 4 | ixtapa
# Processing Record 46 of Set 4 | limenaria
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | channel-port aux basques
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | christchurch
# Processing Record 4 of Set 5 | roald
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | yellowknife
# Processing Record 7 of Set 5 | delano
# Processing Record 8 of Set 5 | dasoguz
# Processing Record 9 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 5 | riosucio
# Processing Record 11 of Set 5 | sal rei
# Processing Record 12 of Set 5 | isiro
# Processing Record 13 of Set 5 | escanaba
# Processing Record 14 of Set 5 | sept-iles
# Processing Record 15 of Set 5 | mawlaik
# Processing Record 16 of Set 5 | saskylakh
# Processing Record 17 of Set 5 | linares
# Processing Record 18 of Set 5 | trairi
# Processing Record 19 of Set 5 | culipapa
# City not found. Skipping...
# Processing Record 20 of Set 5 | algiers
# Processing Record 21 of Set 5 | arlit
# Processing Record 22 of Set 5 | izhma
# Processing Record 23 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 5 | matias romero
# Processing Record 27 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 5 | dillon
# Processing Record 29 of Set 5 | elko
# Processing Record 30 of Set 5 | svetlaya
# Processing Record 31 of Set 5 | saraland
# Processing Record 32 of Set 5 | celestun
# Processing Record 33 of Set 5 | jieshi
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | kholmogory
# Processing Record 36 of Set 5 | kuusamo
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | rock sound
# Processing Record 40 of Set 5 | daru
# Processing Record 41 of Set 5 | dutse
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 5 | guilin
# Processing Record 45 of Set 5 | tual
# Processing Record 46 of Set 5 | puerto ayora
# Processing Record 47 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 5 | linda
# Processing Record 49 of Set 5 | waipawa
# Processing Record 50 of Set 5 | verkhniy fiagdon
# Processing Record 1 of Set 6 | faanui
# Processing Record 2 of Set 6 | aljezur
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | atotonilco el grande
# Processing Record 5 of Set 6 | iwaki
# Processing Record 6 of Set 6 | tongren
# Processing Record 7 of Set 6 | safford
# Processing Record 8 of Set 6 | gladstone
# Processing Record 9 of Set 6 | pundaguitan
# Processing Record 10 of Set 6 | guia de isora
# Processing Record 11 of Set 6 | dicabisagan
# Processing Record 12 of Set 6 | izvestkovyy
# Processing Record 13 of Set 6 | barsovo
# Processing Record 14 of Set 6 | zemio
# Processing Record 15 of Set 6 | urumqi
# Processing Record 16 of Set 6 | port hedland
# Processing Record 17 of Set 6 | kiruna
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | sfantu gheorghe
# Processing Record 20 of Set 6 | kingman
# Processing Record 21 of Set 6 | hofn
# Processing Record 22 of Set 6 | hasaki
# Processing Record 23 of Set 6 | masvingo
# Processing Record 24 of Set 6 | abadan
# Processing Record 25 of Set 6 | elizabethton
# Processing Record 26 of Set 6 | saint-dizier
# Processing Record 27 of Set 6 | tupi paulista
# Processing Record 28 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 6 | xuddur
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | mayo
# Processing Record 32 of Set 6 | coihueco
# Processing Record 33 of Set 6 | khorixas
# Processing Record 34 of Set 6 | new philadelphia
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | hovd
# Processing Record 37 of Set 6 | aleksandrov gay
# Processing Record 38 of Set 6 | jacareacanga
# Processing Record 39 of Set 6 | male
# Processing Record 40 of Set 6 | nadym
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | dapaong
# Processing Record 43 of Set 6 | bontang
# Processing Record 44 of Set 6 | mahebourg
# Processing Record 45 of Set 6 | adrar
# Processing Record 46 of Set 6 | yulara
# Processing Record 47 of Set 6 | santa cruz
# Processing Record 48 of Set 6 | vasudevanallur
# Processing Record 49 of Set 6 | minot
# Processing Record 50 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 7 | high level
# Processing Record 2 of Set 7 | himora
# City not found. Skipping...
# Processing Record 3 of Set 7 | galesong
# Processing Record 4 of Set 7 | avera
# Processing Record 5 of Set 7 | evensk
# Processing Record 6 of Set 7 | portland
# Processing Record 7 of Set 7 | kondinskoye
# Processing Record 8 of Set 7 | san ramon
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | maragogi
# Processing Record 11 of Set 7 | rio das ostras
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 7 | hobyo
# Processing Record 14 of Set 7 | lithgow
# Processing Record 15 of Set 7 | utete
# Processing Record 16 of Set 7 | burns lake
# Processing Record 17 of Set 7 | bukama
# Processing Record 18 of Set 7 | sao joao do piaui
# Processing Record 19 of Set 7 | vila franca do campo
# Processing Record 20 of Set 7 | rockland
# Processing Record 21 of Set 7 | kamaishi
# Processing Record 22 of Set 7 | ulaanbaatar
# Processing Record 23 of Set 7 | sonipat
# Processing Record 24 of Set 7 | makat
# Processing Record 25 of Set 7 | omsukchan
# Processing Record 26 of Set 7 | nouadhibou
# Processing Record 27 of Set 7 | tasiilaq
# Processing Record 28 of Set 7 | wewak
# Processing Record 29 of Set 7 | nicolas bravo
# Processing Record 30 of Set 7 | ust-ilimsk
# Processing Record 31 of Set 7 | sarangani
# Processing Record 32 of Set 7 | masallatah
# Processing Record 33 of Set 7 | krumovgrad
# Processing Record 34 of Set 7 | javanrud
# Processing Record 35 of Set 7 | nueva germania
# Processing Record 36 of Set 7 | kungurtug
# Processing Record 37 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | kailua
# Processing Record 40 of Set 7 | soc trang
# Processing Record 41 of Set 7 | leipzig
# Processing Record 42 of Set 7 | yeppoon
# Processing Record 43 of Set 7 | saint-leu
# Processing Record 44 of Set 7 | zabaykalsk
# Processing Record 45 of Set 7 | alsfeld
# Processing Record 46 of Set 7 | kifri
# Processing Record 47 of Set 7 | lahij
# Processing Record 48 of Set 7 | saldanha
# Processing Record 49 of Set 7 | ayios kirikos
# City not found. Skipping...
# Processing Record 50 of Set 7 | whitehorse
# Processing Record 1 of Set 8 | along
# Processing Record 2 of Set 8 | noumea
# Processing Record 3 of Set 8 | severo-kurilsk
# Processing Record 4 of Set 8 | maxixe
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | sembe
# Processing Record 7 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 8 | preobrazheniye
# Processing Record 9 of Set 8 | makakilo city
# Processing Record 10 of Set 8 | basco
# Processing Record 11 of Set 8 | wajir
# Processing Record 12 of Set 8 | gazli
# Processing Record 13 of Set 8 | samana
# Processing Record 14 of Set 8 | ocumare del tuy
# Processing Record 15 of Set 8 | itarema
# Processing Record 16 of Set 8 | port pirie
# Processing Record 17 of Set 8 | pareora
# Processing Record 18 of Set 8 | aitape
# Processing Record 19 of Set 8 | kavieng
# Processing Record 20 of Set 8 | las vegas
# Processing Record 21 of Set 8 | takoradi
# Processing Record 22 of Set 8 | scarborough
# Processing Record 23 of Set 8 | chiredzi
# Processing Record 24 of Set 8 | caravelas
# Processing Record 25 of Set 8 | belogradcik
# City not found. Skipping...
# Processing Record 26 of Set 8 | newport
# Processing Record 27 of Set 8 | visby
# Processing Record 28 of Set 8 | kruisfontein
# Processing Record 29 of Set 8 | inongo
# Processing Record 30 of Set 8 | potchefstroom
# Processing Record 31 of Set 8 | monrovia
# Processing Record 32 of Set 8 | lypova dolyna
# Processing Record 33 of Set 8 | scottsbluff
# Processing Record 34 of Set 8 | verkhoyansk
# Processing Record 35 of Set 8 | rorvik
# Processing Record 36 of Set 8 | codrington
# Processing Record 37 of Set 8 | broome
# Processing Record 38 of Set 8 | katyuzhanka
# Processing Record 39 of Set 8 | beoumi
# Processing Record 40 of Set 8 | esperance
# Processing Record 41 of Set 8 | prata
# Processing Record 42 of Set 8 | nassau
# Processing Record 43 of Set 8 | polis
# Processing Record 44 of Set 8 | ust-kulom
# Processing Record 45 of Set 8 | gazojak
# Processing Record 46 of Set 8 | belmonte
# Processing Record 47 of Set 8 | gizo
# Processing Record 48 of Set 8 | port blair
# Processing Record 49 of Set 8 | guider
# Processing Record 50 of Set 8 | klaeng
# Processing Record 1 of Set 9 | matli
# Processing Record 2 of Set 9 | chiriqui grande
# Processing Record 3 of Set 9 | bela
# Processing Record 4 of Set 9 | san jose
# Processing Record 5 of Set 9 | nefteyugansk
# Processing Record 6 of Set 9 | mercedes
# Processing Record 7 of Set 9 | chimoio
# Processing Record 8 of Set 9 | qiongshan
# Processing Record 9 of Set 9 | sirajganj
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | khandyga
# Processing Record 12 of Set 9 | namatanai
# Processing Record 13 of Set 9 | palmer
# Processing Record 14 of Set 9 | ginda
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | pitimbu
# Processing Record 17 of Set 9 | te anau
# Processing Record 18 of Set 9 | saint-georges
# Processing Record 19 of Set 9 | raudeberg
# Processing Record 20 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 9 | galle
# Processing Record 22 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 9 | qinzhou
# Processing Record 24 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 9 | berlevag
# Processing Record 26 of Set 9 | surt
# Processing Record 27 of Set 9 | acari
# Processing Record 28 of Set 9 | concepcion del oro
# Processing Record 29 of Set 9 | plouzane
# Processing Record 30 of Set 9 | salekhard
# Processing Record 31 of Set 9 | ondjiva
# Processing Record 32 of Set 9 | half moon bay
# Processing Record 33 of Set 9 | clyde river
# Processing Record 34 of Set 9 | lahaina
# Processing Record 35 of Set 9 | mgandu
# Processing Record 36 of Set 9 | tuatapere
# Processing Record 37 of Set 9 | san cristobal
# Processing Record 38 of Set 9 | lashio
# Processing Record 39 of Set 9 | vostok
# Processing Record 40 of Set 9 | nicoya
# Processing Record 41 of Set 9 | cartagena del chaira
# Processing Record 42 of Set 9 | darhan
# Processing Record 43 of Set 9 | kot putli
# City not found. Skipping...
# Processing Record 44 of Set 9 | westerly
# Processing Record 45 of Set 9 | sobolevo
# Processing Record 46 of Set 9 | varzea grande
# Processing Record 47 of Set 9 | shingu
# Processing Record 48 of Set 9 | nador
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | tirumullaivasal
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 2 of Set 10 | glenwood springs
# Processing Record 3 of Set 10 | ballina
# Processing Record 4 of Set 10 | dalbandin
# Processing Record 5 of Set 10 | buta
# Processing Record 6 of Set 10 | ust-nera
# Processing Record 7 of Set 10 | khandbari
# Processing Record 8 of Set 10 | aklavik
# Processing Record 9 of Set 10 | osakarovka
# Processing Record 10 of Set 10 | bilibino
# Processing Record 11 of Set 10 | vao
# Processing Record 12 of Set 10 | kawalu
# Processing Record 13 of Set 10 | zaozerne
# Processing Record 14 of Set 10 | panzhihua
# Processing Record 15 of Set 10 | metehara
# City not found. Skipping...
# Processing Record 16 of Set 10 | scalea
# Processing Record 17 of Set 10 | gorontalo
# Processing Record 18 of Set 10 | kutum
# Processing Record 19 of Set 10 | olinda
# Processing Record 20 of Set 10 | grand gaube
# Processing Record 21 of Set 10 | candido de abreu
# Processing Record 22 of Set 10 | sabha
# Processing Record 23 of Set 10 | angoche
# Processing Record 24 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 25 of Set 10 | ancud
# Processing Record 26 of Set 10 | iskateley
# Processing Record 27 of Set 10 | ravar
# Processing Record 28 of Set 10 | lensk
# Processing Record 29 of Set 10 | nakamura
# Processing Record 30 of Set 10 | vila
# Processing Record 31 of Set 10 | lala
# Processing Record 32 of Set 10 | livingstonia
# Processing Record 33 of Set 10 | agde
# Processing Record 34 of Set 10 | cayenne
# Processing Record 35 of Set 10 | fort pierce
# Processing Record 36 of Set 10 | shenjiamen
# Processing Record 37 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 10 | pavilosta
# Processing Record 39 of Set 10 | tungor
# Processing Record 40 of Set 10 | batticaloa
# Processing Record 41 of Set 10 | vianden
# Processing Record 42 of Set 10 | margate
# Processing Record 43 of Set 10 | sinjai
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | mezen
# Processing Record 46 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 10 | szob
# Processing Record 48 of Set 10 | urman
# Processing Record 49 of Set 10 | kidal
# Processing Record 50 of Set 10 | lagoa
# Processing Record 1 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 11 | nome
# Processing Record 3 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 11 | kontagora
# Processing Record 5 of Set 11 | ratnagiri
# Processing Record 6 of Set 11 | bayangol
# Processing Record 7 of Set 11 | tondano
# Processing Record 8 of Set 11 | bonnyville
# Processing Record 9 of Set 11 | hammerfest
# Processing Record 10 of Set 11 | lincoln
# Processing Record 11 of Set 11 | ishigaki
# Processing Record 12 of Set 11 | edson
# Processing Record 13 of Set 11 | shemonaikha
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | laguna
# Processing Record 16 of Set 11 | gweta
# Processing Record 17 of Set 11 | padang
# Processing Record 18 of Set 11 | sovetskiy
# Processing Record 19 of Set 11 | ilo
# Processing Record 20 of Set 11 | correntina
# Processing Record 21 of Set 11 | yamada
# Processing Record 22 of Set 11 | kieta
# Processing Record 23 of Set 11 | mudgee
# Processing Record 24 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 25 of Set 11 | sorong
# Processing Record 26 of Set 11 | chiang klang
# Processing Record 27 of Set 11 | blensong
# City not found. Skipping...
# Processing Record 28 of Set 11 | kasongo-lunda
# Processing Record 29 of Set 11 | belaya gora
# Processing Record 30 of Set 11 | balabac
# Processing Record 31 of Set 11 | holland
# Processing Record 32 of Set 11 | ndende
# Processing Record 33 of Set 11 | vuktyl
# Processing Record 34 of Set 11 | opuwo
# Processing Record 35 of Set 11 | abu samrah
# Processing Record 36 of Set 11 | sibolga
# Processing Record 37 of Set 11 | kushima
# Processing Record 38 of Set 11 | thoen
# Processing Record 39 of Set 11 | masuguru
# Processing Record 40 of Set 11 | port hardy
# Processing Record 41 of Set 11 | tumaco
# Processing Record 42 of Set 11 | canakkale
# Processing Record 43 of Set 11 | college
# Processing Record 44 of Set 11 | roma
# Processing Record 45 of Set 11 | terrell
# Processing Record 46 of Set 11 | lovozero
# Processing Record 47 of Set 11 | katherine
# Processing Record 48 of Set 11 | taltal
# Processing Record 49 of Set 11 | monki
# Processing Record 50 of Set 11 | porbandar
# Processing Record 1 of Set 12 | murray
# Processing Record 2 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 12 | limbe
# Processing Record 4 of Set 12 | san luis
# Processing Record 5 of Set 12 | igarka
# Processing Record 6 of Set 12 | asau
# Processing Record 7 of Set 12 | shimanovsk
# Processing Record 8 of Set 12 | togur
# Processing Record 9 of Set 12 | mattru
# Processing Record 10 of Set 12 | tazovskiy
# Processing Record 11 of Set 12 | plettenberg bay
# Processing Record 12 of Set 12 | aichach
# Processing Record 13 of Set 12 | cherskiy
# Processing Record 14 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 12 | ulladulla
# Processing Record 16 of Set 12 | bethanien
# Processing Record 17 of Set 12 | red bluff
# Processing Record 18 of Set 12 | shelburne
# Processing Record 19 of Set 12 | soure
# Processing Record 20 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 12 | deputatskiy
# Processing Record 22 of Set 12 | jiuquan
# Processing Record 23 of Set 12 | nemuro
# Processing Record 24 of Set 12 | esfahan
# Processing Record 25 of Set 12 | soria
# Processing Record 26 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 27 of Set 12 | sao joao da barra
# Processing Record 28 of Set 12 | quimper
# Processing Record 29 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 30 of Set 12 | kodinsk
# Processing Record 31 of Set 12 | lixourion
# Processing Record 32 of Set 12 | kargil
# Processing Record 33 of Set 12 | sonqor
# Processing Record 34 of Set 12 | tigil
# Processing Record 35 of Set 12 | brewster
# Processing Record 36 of Set 12 | san miguelito
# Processing Record 37 of Set 12 | port augusta
# Processing Record 38 of Set 12 | aksu
# Processing Record 39 of Set 12 | fort nelson
# Processing Record 40 of Set 12 | talnakh
# Processing Record 41 of Set 12 | yarada
# Processing Record 42 of Set 12 | pachino
# Processing Record 43 of Set 12 | shiyan
# Processing Record 44 of Set 12 | manubah
# City not found. Skipping...
# Processing Record 45 of Set 12 | luganville
# Processing Record 46 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 12 | kisangani
# Processing Record 48 of Set 12 | sakakah
# Processing Record 49 of Set 12 | divnoye
# Processing Record 50 of Set 12 | key largo
# Processing Record 1 of Set 13 | fort morgan
# Processing Record 2 of Set 13 | kemijarvi
# Processing Record 3 of Set 13 | malakal
# Processing Record 4 of Set 13 | doha
# Processing Record 5 of Set 13 | woodway
# Processing Record 6 of Set 13 | nanortalik
# Processing Record 7 of Set 13 | moura
# Processing Record 8 of Set 13 | puerto ayacucho
# Processing Record 9 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 10 of Set 13 | bacolod
# Processing Record 11 of Set 13 | ahuimanu
# Processing Record 12 of Set 13 | djougou
# Processing Record 13 of Set 13 | pervomayskoye
# Processing Record 14 of Set 13 | katsuura
# Processing Record 15 of Set 13 | flinders
# Processing Record 16 of Set 13 | stornoway
# Processing Record 17 of Set 13 | fortuna
# Processing Record 18 of Set 13 | boa vista
# Processing Record 19 of Set 13 | champerico
# Processing Record 20 of Set 13 | husavik
# Processing Record 21 of Set 13 | ozu
# Processing Record 22 of Set 13 | bardiyah
# Processing Record 23 of Set 13 | phan thiet
# Processing Record 24 of Set 13 | buchanan
# Processing Record 25 of Set 13 | huaidian
# Processing Record 26 of Set 13 | amot
# Processing Record 27 of Set 13 | santa maria
# Processing Record 28 of Set 13 | nalut
# Processing Record 29 of Set 13 | altay
# Processing Record 30 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 13 | mahibadhoo
# Processing Record 32 of Set 13 | camacha
# Processing Record 33 of Set 13 | bowling green
# Processing Record 34 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 35 of Set 13 | damietta
# Processing Record 36 of Set 13 | giresun
# Processing Record 37 of Set 13 | zhezkazgan
# Processing Record 38 of Set 13 | umm kaddadah
# Processing Record 39 of Set 13 | natalio
# Processing Record 40 of Set 13 | dukat
# Processing Record 41 of Set 13 | peniche
# Processing Record 42 of Set 13 | santa maria del oro
# Processing Record 43 of Set 13 | corinto
# Processing Record 44 of Set 13 | la ronge
# Processing Record 45 of Set 13 | boyolangu
# Processing Record 46 of Set 13 | honningsvag
# Processing Record 47 of Set 13 | ilmajoki
# Processing Record 48 of Set 13 | gasa
# Processing Record 49 of Set 13 | sarakhs
# Processing Record 50 of Set 13 | isangel
# Processing Record 1 of Set 14 | benoni
# Processing Record 2 of Set 14 | luderitz
# Processing Record 3 of Set 14 | egvekinot
# Processing Record 4 of Set 14 | desaguadero
# Processing Record 5 of Set 14 | jega
# Processing Record 6 of Set 14 | loandjili
# Processing Record 7 of Set 14 | isahaya
# Processing Record 8 of Set 14 | mikhaylovskoye
# Processing Record 9 of Set 14 | suntar
# Processing Record 10 of Set 14 | bam
# Processing Record 11 of Set 14 | touros
# Processing Record 12 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 14 | whyalla
# Processing Record 14 of Set 14 | rundu
# Processing Record 15 of Set 14 | ozinki
# Processing Record 16 of Set 14 | silifke
# Processing Record 17 of Set 14 | helong
# Processing Record 18 of Set 14 | puerto colombia
# Processing Record 19 of Set 14 | tisul
# Processing Record 20 of Set 14 | bathsheba
# Processing Record 21 of Set 14 | aviles
# Processing Record 22 of Set 14 | praya
# Processing Record 23 of Set 14 | moron
# Processing Record 24 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 25 of Set 14 | bairiki
# Processing Record 26 of Set 14 | aras
# Processing Record 27 of Set 14 | pappadatai
# Processing Record 28 of Set 14 | rio verde de mato grosso
# Processing Record 29 of Set 14 | pangnirtung
# Processing Record 30 of Set 14 | tiznit
# Processing Record 31 of Set 14 | fairbanks
# Processing Record 32 of Set 14 | verkhnevilyuysk
# Processing Record 33 of Set 14 | vicosa do ceara
# Processing Record 34 of Set 14 | salinopolis
# Processing Record 35 of Set 14 | linqing
# Processing Record 36 of Set 14 | bozeman
# Processing Record 37 of Set 14 | falun
# Processing Record 38 of Set 14 | pilar
# Processing Record 39 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 14 | warrnambool
# Processing Record 41 of Set 14 | troitsko-pechorsk
# Processing Record 42 of Set 14 | dingle
# Processing Record 43 of Set 14 | voi
# Processing Record 44 of Set 14 | at-bashi
# Processing Record 45 of Set 14 | baherden
# Processing Record 46 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 14 | lazaro cardenas
# Processing Record 48 of Set 14 | labuhan
# Processing Record 49 of Set 14 | biak
# Processing Record 50 of Set 14 | puerto cabezas
# Processing Record 1 of Set 15 | masiga
# Processing Record 2 of Set 15 | jumla
# Processing Record 3 of Set 15 | agueda
# Processing Record 4 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 15 | natal
# Processing Record 6 of Set 15 | kalispell
# Processing Record 7 of Set 15 | oranjemund
# Processing Record 8 of Set 15 | vostochnyy
# Processing Record 9 of Set 15 | vallenar
# Processing Record 10 of Set 15 | bud
# Processing Record 11 of Set 15 | akropong
# Processing Record 12 of Set 15 | russell
# Processing Record 13 of Set 15 | savannah bight
# Processing Record 14 of Set 15 | pelotas
# Processing Record 15 of Set 15 | lavrentiya
# Processing Record 16 of Set 15 | aykhal
# Processing Record 17 of Set 15 | pontianak
# Processing Record 18 of Set 15 | arrecife
# Processing Record 19 of Set 15 | ayna
# Processing Record 20 of Set 15 | jabinyanah
# Processing Record 21 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 22 of Set 15 | shambu
# Processing Record 23 of Set 15 | chemal
# Processing Record 24 of Set 15 | mogok
# Processing Record 25 of Set 15 | humboldt
# Processing Record 26 of Set 15 | khani
# Processing Record 27 of Set 15 | luebo
# Processing Record 28 of Set 15 | hamilton
# Processing Record 29 of Set 15 | neiafu
# Processing Record 30 of Set 15 | tambopata
# Processing Record 31 of Set 15 | policoro
# Processing Record 32 of Set 15 | harnosand
# Processing Record 33 of Set 15 | bermeo
# Processing Record 34 of Set 15 | pitea
# Processing Record 35 of Set 15 | zuwarah
# Processing Record 36 of Set 15 | makaha
# Processing Record 37 of Set 15 | balikpapan
# Processing Record 38 of Set 15 | paraiso
# Processing Record 39 of Set 15 | eureka
# Processing Record 40 of Set 15 | veranopolis
# Processing Record 41 of Set 15 | uglovka
# Processing Record 42 of Set 15 | saurimo
# Processing Record 43 of Set 15 | henties bay
# Processing Record 44 of Set 15 | sevlievo
# Processing Record 45 of Set 15 | srednekolymsk
# Processing Record 46 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 15 | taian
# Processing Record 48 of Set 15 | puteyets
# Processing Record 49 of Set 15 | rovaniemi
# Processing Record 50 of Set 15 | mumbwa
# Processing Record 1 of Set 16 | turiacu
# Processing Record 2 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 16 | maun
# Processing Record 4 of Set 16 | ambon
# Processing Record 5 of Set 16 | lephepe
# City not found. Skipping...
# Processing Record 6 of Set 16 | karasburg
# Processing Record 7 of Set 16 | wukari
# Processing Record 8 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 16 | sinnamary
# Processing Record 10 of Set 16 | beloha
# Processing Record 11 of Set 16 | loa janan
# Processing Record 12 of Set 16 | gigmoto
# Processing Record 13 of Set 16 | jawhar
# Processing Record 14 of Set 16 | maracaibo
# Processing Record 15 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 16 | kuah
# Processing Record 17 of Set 16 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 16 | nakusp
# Processing Record 19 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 16 | sokoto
# Processing Record 21 of Set 16 | brae
# Processing Record 22 of Set 16 | komsomolskiy
# Processing Record 23 of Set 16 | quelimane
# Processing Record 24 of Set 16 | aripuana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cidreira -30.1811  -50.2056     78.26        86         100
# 1        Ushuaia -54.8000  -68.3000     55.40        58          75
# 2         Castro -24.7911  -50.0119     72.79        79         100
# 3  Cockburn Town  21.4612  -71.1419     78.80        53          40
# 4    Sakaiminato  35.5500  133.2333     39.20        75          75
# 5         Eugene  44.0521 -123.0867     51.01        87          90
# 6        Salalah  17.0151   54.0924     71.60        64           0
# 7     Kaitangata -46.2817  169.8464     56.14        81         100
# 8      Dong Xoai  11.5333  106.9167     70.21        78          24
# 9         Albany  42.6001  -73.9662     19.00        48         100
#
#    Wind Speed Country Current Description
# 0        7.40      BR     overcast clouds
# 1        2.30      AR       broken clouds
# 2        8.46      BR     overcast clouds
# 3       12.66      TC    scattered clouds
# 4        3.44      JP       broken clouds
# 5        8.05      US     overcast clouds
# 6        3.44      OM           clear sky
# 7        1.68      NZ     overcast clouds
# 8        3.96      VN          few clouds
# 9        3.02      US     overcast clouds

# %%
new_column_order = ["City","Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cidreira      BR -30.1811  -50.2056     78.26        86         100
# 1        Ushuaia      AR -54.8000  -68.3000     55.40        58          75
# 2         Castro      BR -24.7911  -50.0119     72.79        79         100
# 3  Cockburn Town      TC  21.4612  -71.1419     78.80        53          40
# 4    Sakaiminato      JP  35.5500  133.2333     39.20        75          75
# 5         Eugene      US  44.0521 -123.0867     51.01        87          90
# 6        Salalah      OM  17.0151   54.0924     71.60        64           0
# 7     Kaitangata      NZ -46.2817  169.8464     56.14        81         100
# 8      Dong Xoai      VN  11.5333  106.9167     70.21        78          24
# 9         Albany      US  42.6001  -73.9662     19.00        48         100
#
#    Wind Speed Current Description
# 0        7.40     overcast clouds
# 1        2.30       broken clouds
# 2        8.46     overcast clouds
# 3       12.66    scattered clouds
# 4        3.44       broken clouds
# 5        8.05     overcast clouds
# 6        3.44           clear sky
# 7        1.68     overcast clouds
# 8        3.96          few clouds
# 9        3.02     overcast clouds

# %%
city_data_df.count()
# Out:
# City                   700
# Country                700
# Lat                    700
# Lng                    700
# Max Temp               700
# Humidity               700
# Cloudiness             700
# Wind Speed             700
# Current Description    700
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
